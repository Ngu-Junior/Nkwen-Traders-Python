# %% [markdown]
# # Snippet 1 — Daily Sales Loop

# %%
daily_sales = [12000, 15500, 9800, 21000, 17250]
for i in range(1, len(daily_sales)+1):
 print(f"Day {i}: {daily_sales[i-1]} FCFA")
# Out:
# Day 1: 12000 FCFA
# Day 2: 15500 FCFA
# Day 3: 9800 FCFA
# Day 4: 21000 FCFA
# Day 5: 17250 FCFA

# %%
#Snippet 1
# logic error
#the problem with this code is that range that has been passed into it only runs from 1-4 instead of 1-5 cause the last value of the range function
# is not inclusive.
# HAD TO COUNT THROUGH THE LOOP BY HAND ONE AT A TIME JUST TO REALISE THAT THE THE RANGE FUNCTION WAS ONLY 4 OUTPUT VALUES 1-5 WITH 5 NOT INCLUSIVE
# i had to increase the len by 1 that is "len(daily_sales)+1)" instead of "len(daily_sales))" 
# i also had to change from "{daily_sales[i]} FCFA")" to '{daily_sales[i-1]} FCFA")'since the index of a list starts at zero but i start iterating from
# 1 and goes upward

# %% [markdown]
# # Snippet 2 — Formatted Receipt Line

# %%
product_name = "Cooking Oil 5L"
price = 6500
quantity = 3
receipt_line = "Item: " + product_name + " | Total: " + str(price * quantity) + "FCFA"
print(receipt_line)
# Out:
# Item: Cooking Oil 5L | Total: 19500FCFA

# %%
#Snippet 2
# the problem with this code is that we can not concatenate a string and an interger
# I had to read the error message and follow to the indicated line that had the error. and i found out that the (price * quantity) was
# returning and interger and not a string so i had to convert it to a string using the string key word "str" in order to concatenate

# %% [markdown]
# # Snippet 3 — Stock Status Check

# %%
quantity = 20
if quantity == 0:
 status = "Out of Stock"
elif quantity <= 10:
 status = "Low Stock"
else:
 status = "Well Stocked"
print(f"Status: {status}")
# Out:
# Status: Well Stocked

# %%
#Snippet 3
# the only problem with this code was an indentation error which i had to look through the lines and fixed it

# %% [markdown]
# # Snippet 4 — Total Inventory Value

# %%
products = [
 {"name": "Rice 25kg Bag", "price": 15000, "quantity": 12},
 {"name": "Sugar 1kg", "price": 900, "quantity": 50},
 {"name": "Bread Loaf", "price": 700, "quantity": 30},
]
total_value = 0
for product in products:
 total_value += product["price"] * product["quantity"]
 #print(total_value)
print(f"Total inventory value: {total_value} FCFA")
# Out:
# 180000
# 225000
# 246000
# Total inventory value: 246000 FCFA

# %%
#Snippet 4
# logic error
# here with this code it was quite tricky as they were no error message at all so i had to include a print statement within the for loop
# then i discovered that it was not adding the results of the different dictionaries in the list together but just printing the total value of each
#dictionary. so i had to change the code from "total_value = product["price"] * product["quantity"]" to 
#"total_value += product["price"] * product["quantity"]" by just adding a "+".

# %% [markdown]
# # Snippet 5 — Average Sale Per Customer

# %%
customer_count = 12
total_sales = 186000
average_per_customer = total_sales / customer_count
print("Average sale per customer: ", + average_per_customer)
# Out:
# Average sale per customer:  15500.0

# %%
# Snippet 5
# so here in this code we had two bugs the first of which was an  unsupported operand type(s) for /: 'int' and 'str'on line 3
# i had to go back to customer count and change it to an interger.
# the second bug was can only concatenate str (not "float") to str , but the code was not trying to concatenate but rather trying to print side by side
# all that was lacking was just a comma which i included and it ran successfully
